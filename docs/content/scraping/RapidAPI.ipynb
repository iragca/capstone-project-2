# %% [markdown]
# # RapidApiScraper
#
# [`Source`](https://github.com/iragca/capstone-project-2/blob/master/src/scraper/RapidApi.py)
#
# This API mainly utilizes this two APIs:
#
# 1. https://rapidapi.com/datahungrybeast/api/twitter154
# 2. https://rapidapi.com/alexanderxbx/api/twitter-api45
#
# On these endpoints respectively:
#
# 1. https://rapidapi.com/datahungrybeast/api/twitter154/playground/apiendpoint_946330d9-6af4-4f51-b36c-79b2276a0928
# 2. https://rapidapi.com/alexanderxbx/api/twitter-api45/playground/apiendpoint_b4db8ee2-25bc-4743-934d-8b9b4e774bd7

# %% [markdown]
# ````{card}
# :class-header: bg-light
# :class-card: border-0 shadow-none
#
# Parameters
# ^^^
# `api_key` (str)
# :   The [RapidAPI](https://rapidapi.com/) token key used to authenticate API use.
# ````
#
# ````{card}
# :class-header: bg-light
# :class-card: border-0 shadow-none
#
# Attributes
# ^^^
# `api_key` (str)
# :   The [RapidAPI](https://rapidapi.com/) token key used to authenticate API use.
# ````

# %%
from src.scraper import RapidApiScraper

# %% [markdown]
# ## Methods
#
# ### `get_user_info_by_twitter_api4`
#
# Parameters
# :   `username` (*str*) -- Username to get
# :   `user_id` (*str | None*) -- User
#
# Returns:
# :   *dict* -- Returns the user data JSON from the API.
#
# ### `get_users_tweets_by_twitter_api45`
#
# Parameters
# :   `username` (*str*) -- Username to get
# :   `expected_num_tweets` (*int*) -- The maximum/expected amount of tweets you get for the user
#
# Returns:
# :   *list[dict]* -- Returns a *list* of tweets as a *dict*.
