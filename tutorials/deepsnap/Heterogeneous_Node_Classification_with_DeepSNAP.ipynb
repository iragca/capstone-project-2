# %% [markdown]
# # **Heterogeneous Node Classification with DeepSNAP**
#
# Heterogeneous graphs extend the traditional homogenous graphs by specifically incorperating different node and edge types. This additional information allows us to extend the traditional graph neural nework models, such as applying the heterogenous message passing, where different message types now exist between different node, edge type relationships.
#
# In this tutorial, we will build a heterogenous graph neural netowrk model by using [PyTorch Geonetric](https://pytorch-geometric.readthedocs.io/en/latest/) and [DeepSNAP](https://snap.stanford.edu/deepsnap/) on the heterogeneous node property prediction (node classification) task.

# %% [markdown]
# # Device
#
# Please click `Runtime` and then `Change runtime type`. Then set the `hardware accelerator` to **GPU**.

# %% [markdown]
# # Installation

# %%
# %pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# %pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# %pip install -q torch-geometric
# %pip install -q git+https://github.com/snap-stanford/deepsnap.git
# Out:
#      |████████████████████████████████| 2.6MB 311kB/s
#      |████████████████████████████████| 1.4MB 7.5MB/s
#      |████████████████████████████████| 225kB 8.4MB/s
#      |████████████████████████████████| 235kB 45.7MB/s
#      |████████████████████████████████| 51kB 9.2MB/s
#   Building wheel for torch-geometric (setup.py) ... done
#   Building wheel for deepsnap (setup.py) ... done

# %% [markdown]
# # Heterogeneous Graph Node Classification
#
# In this tutorial, we will use PyTorch Geometric and DeepSNAP to implement a GNN model for heterogeneous graph node property prediction (node classification).
#
# At first let's take look at the general structure of a heterogeneous layer by an example.
#
# Let's assume we have a graph $G$, which contains two node types $a$ and $b$, and three message types $m_1=(a, r_1, a)$, $m_2=(a, r_2, b)$ and $m_3=(a, r_3, b)$.
#
# Thus, for $G$ a heterogeneous layer will contains three Heterogeneous GNN layers (`HeteroGNNConv` in this Colab) where each `HeteroGNNConv` layer will perform the message passing and aggregation with respect to only one message type. The overview of the heterogeneous layer is shown below:
#
# <br/>
# <center>
# <img src="https://web.stanford.edu/class/cs224w/images/colab4/hetero_conv.png"/>
# </center>
# <br/>
#
# In this Colab, all the $l^{th}$ Heterogeneous GNN layers will be managed by a ($l^{th}$) Heterogeneous GNN Wrapper layer (the `HeteroGNNWrapperConv`). The $l^{th}$ Heterogeneous GNN Wrapper layer will take in the input node embeddings from $(l-1)^{th}$ layer and aggregate (across message types) the Heterogeneous GNN layers' results. For example, the wrapper layer will aggregate node type $b$'s node embeddings from Heterogeneous GNN layers for $m_2$ and $m_3$. The "simplified" heterogeneous layer structure is shown below:
#
# <br/>
# <center>
# <img src="http://web.stanford.edu/class/cs224w/images/colab4/hetero_conv_1.png"/>
# </center>
# <br/>

# %% [markdown]
# ## Setup

# %%
import copy
import torch
import deepsnap
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric.nn as pyg_nn

from sklearn.metrics import f1_score
from deepsnap.hetero_gnn import forward_op
from deepsnap.hetero_graph import HeteroGraph
from torch_sparse import SparseTensor, matmul

# %% [markdown]
# ## Heterogeneous GNN Layer
#
# Now let's start working on our own implementation of a heterogeneous layer (the `HeteroGNNConv`)! In general, our heterogeneous GNN layer draws ideas from the **GraphSAGE** ([Hamilton et al. (2017)](https://arxiv.org/abs/1706.02216)).
#
# At first, let's implement the GNN layer for each message type:
#
# \begin{equation}
# m =(s, r, d)
# \end{equation}
#
# Each message type is a tuple containing three elements where $s$ refers to the source node type, $r$ refers to the edge (relation) type and $d$ refers to the destination node type. The update rule is very similar to that of GraphSAGE but we need to include the node types and the edge type. The update rule is described as below:
#
# \begin{equation}
# h_v^{(l)[m]} = W^{(l)[m]} \cdot \text{CONCAT} \Big( W_d^{(l)[m]} \cdot h_v^{(l-1)}, W_s^{(l)[m]} \cdot AGG(\{h_u^{(l-1)}, \forall u \in N_{m}(v) \})\Big)
# \end{equation}
#
# where $[m]$ indicates that the weight matrices or embeddings with respect to message type $m$, $W_s^{(l)[m]}$ computes the messages from neighboring nodes, $W_d^{(l)[m]}$ compute messages from the node itself, and $W^{(l)[m]}$ aggregates messages from both node types. In the equation above, $v$ has the node type $d$, and $u$ has the node type $s$.
#
# For simplicity, we use mean aggregations for $AGG$ where:
#
# \begin{equation}
# AGG(\{h_u^{(l-1)}, \forall u \in N_{m}(v) \}) = \frac{1}{|N_{m}(v)|} \sum_{u\in N_{m}(v)} h_u^{(l-1)}
# \end{equation}

# %%
class HeteroGNNConv(pyg_nn.MessagePassing):
    def __init__(self, in_channels_src, in_channels_dst, out_channels):
        super(HeteroGNNConv, self).__init__(aggr="mean")

        self.in_channels_src = in_channels_src
        self.in_channels_dst = in_channels_dst
        self.out_channels = out_channels

        self.lin_src = nn.Linear(self.in_channels_src, self.out_channels)
        self.lin_dst = nn.Linear(self.in_channels_dst, self.out_channels)
        self.lin_update = nn.Linear(self.out_channels * 2, self.out_channels)

    def forward(
        self,
        node_feature_src,
        node_feature_dst,
        edge_index,
        size=None
    ):
        return self.propagate(
            edge_index, size=size,
            node_feature_dst=node_feature_dst,
            node_feature_src=node_feature_src
        )

    def message_and_aggregate(self, edge_index, node_feature_src):
        out = matmul(edge_index, node_feature_src, reduce="mean")
        return out

    def update(self, aggr_out, node_feature_dst):
        aggr_out = self.lin_src(aggr_out)
        node_feature_dst = self.lin_dst(node_feature_dst)
        aggr_out = torch.cat([aggr_out, node_feature_dst], dim=-1)
        aggr_out = self.lin_update(aggr_out)
        return aggr_out

# %% [markdown]
# ## Heterogeneous GNN Wrapper Layer
#
# After implementing the GNN layer for each message type, we need to aggregate the the node embedding results (with respect to each message types) together. Here we will implement two types of message type level aggregation.
#
# The first one is simply the mean aggregation:
#
# \begin{equation}
# h_v^{(l)} = \frac{1}{M}\sum_{m=1}^{M}h_v^{(l)[m]}
# \end{equation}
#
# Here node $v$ has the node type $d$ and $M$ is the total number of message types that the destination node type is $d$.
#
# The other one is the semantic level attention introduced in **HAN** ([Wang et al. (2019)](https://arxiv.org/abs/1903.07293)). Instead of directly averaging on the message type aggregation results, we can use attention to learn which message type result can be more important, then aggregate from all the message types. Following are the equations for semantic level attention:
#
# \begin{equation}
# e_{m} = \frac{1}{|V_{d}|} \sum_{v \in V_{d}} q_{attn}^T \cdot tanh \Big( W_{attn}^{(l)} \cdot h_v^{(l)[m]} + b \Big)
# \end{equation}
#
# where $m$ refers to message type and $d$ refers to the destination node type. Then we can compute the attention and update the $h_v^{(l)}$:
#
# \begin{equation}
# \alpha_{m} = \frac{\exp(e_{m})}{\sum_{m=1}^M \exp(e_{m})}
# \end{equation}
#
# \begin{equation}
# h_v^{(l)} = \sum_{m=1}^{M} \alpha_{m} \cdot h_v^{(l)[m]}
# \end{equation}
#
# **Notice**: You can directly use `deepsnap.hetero_gnn.HeteroConv` directly for the mean aggregation. Here we overide the `HeteroConv` in order to support the semantic level attention.

# %%
class HeteroGNNWrapperConv(deepsnap.hetero_gnn.HeteroConv):
    def __init__(self, convs, args, aggr="mean"):
        super(HeteroGNNWrapperConv, self).__init__(convs, None)
        self.aggr = aggr

        # Map the index and message type
        self.mapping = {}

        # A numpy array that stores the final attention probability
        self.alpha = None

        if self.aggr == "attn":
            self.attn_proj = nn.Sequential(
                nn.Linear(args['hidden_size'], args['attn_size']),
                nn.Tanh(),
                nn.Linear(args['attn_size'], 1, bias=False)
            )

    def reset_parameters(self):
        super(HeteroConvWrapper, self).reset_parameters()
        if self.aggr == "attn":
            for layer in self.attn_proj.children():
                layer.reset_parameters()

    def forward(self, node_features, edge_indices):
        message_type_emb = {}
        for message_key, message_type in edge_indices.items():
            src_type, edge_type, dst_type = message_key
            node_feature_src = node_features[src_type]
            node_feature_dst = node_features[dst_type]
            edge_index = edge_indices[message_key]
            message_type_emb[message_key] = (
                self.convs[message_key](
                    node_feature_src,
                    node_feature_dst,
                    edge_index,
                )
            )
        node_emb = {dst: [] for _, _, dst in message_type_emb.keys()}
        mapping = {}
        for (src, edge_type, dst), item in message_type_emb.items():
            mapping[len(node_emb[dst])] = (src, edge_type, dst)
            node_emb[dst].append(item)
        self.mapping = mapping
        for node_type, embs in node_emb.items():
            if len(embs) == 1:
                node_emb[node_type] = embs[0]
            else:
                node_emb[node_type] = self.aggregate(embs)
        return node_emb

    def aggregate(self, xs):
        if self.aggr == "mean":
            x = torch.stack(xs, dim=-1)
            return x.mean(dim=-1)
        elif self.aggr == "attn":
            N = xs[0].shape[0] # Number of nodes for that node type
            M = len(xs) # Number of message types for that node type

            x = torch.cat(xs, dim=0).view(M, N, -1) # M * N * D
            z = self.attn_proj(x).view(M, N) # M * N * 1
            z = z.mean(1) # M * 1
            alpha = torch.softmax(z, dim=0) # M * 1

            # Store the attention result to self.alpha as np array
            self.alpha = alpha.view(-1).data.cpu().numpy()

            alpha = alpha.view(M, 1, 1)
            x = x * alpha
            return x.sum(dim=0)

# %% [markdown]
# ## Initialize Heterogeneous GNN Layers
#
# Now let's initialize the Heterogeneous GNN Layers. Different from homogeneous graph case, heterogeneous case can be a little bit complex.
#
# In general, we need to create a dictionary of `HeteroGNNConv` layers where the keys are message types.
#
# * To get all message types, we can use `deepsnap.hetero_graph.HeteroGraph.message_types`.
# * If we are initializing the first conv layers, we need to get the feature dimension of each node type. For this we can use `deepsnap.hetero_graph.HeteroGraph.num_node_features(node_type)` which will return the node feature dimension of `node_type`. In this function, we set each `HeteroGNNConv` `out_channels` to be `hidden_size`.
# * If we are not initializing the first conv layers, all node types will have the same embedding dimension `hidden_size` and we still set `HeteroGNNConv` `out_channels` to be `hidden_size` for simplicity.

# %%
def generate_convs(hetero_graph, conv, hidden_size, first_layer=False):
    convs = {}
    for message_type in hetero_graph.message_types:
        if first_layer is True:
            src_type = message_type[0]
            dst_type = message_type[2]
            src_size = hetero_graph.num_node_features(src_type)
            dst_size = hetero_graph.num_node_features(dst_type)
            convs[message_type] = conv(src_size, dst_size, hidden_size)
        else:
            convs[message_type] = conv(hidden_size, hidden_size, hidden_size)
    return convs

# %% [markdown]
# ## HeteroGNN
#
# Now we will make a simple HeteroGNN model which contains only two `HeteroGNNWrapperConv` layers.
#
# For the forward function in `HeteroGNN`, the model is going to be run as following:
#
# $\text{self.convs1} \rightarrow \text{self.bns1} \rightarrow \text{self.relus1} \rightarrow \text{self.convs2} \rightarrow \text{self.bns2} \rightarrow \text{self.relus2} \rightarrow \text{self.post_mps}$

# %%
class HeteroGNN(torch.nn.Module):
    def __init__(self, hetero_graph, args, aggr="mean"):
        super(HeteroGNN, self).__init__()

        self.aggr = aggr
        self.hidden_size = args['hidden_size']

        self.bns1 = nn.ModuleDict()
        self.bns2 = nn.ModuleDict()
        self.relus1 = nn.ModuleDict()
        self.relus2 = nn.ModuleDict()
        self.post_mps = nn.ModuleDict()

        convs1 = generate_convs(hetero_graph, HeteroGNNConv, self.hidden_size, first_layer=True)
        convs2 = generate_convs(hetero_graph, HeteroGNNConv, self.hidden_size)

        self.convs1 = HeteroGNNWrapperConv(convs1, args, aggr=self.aggr)
        self.convs2 = HeteroGNNWrapperConv(convs2, args, aggr=self.aggr)

        for node_type in hetero_graph.node_types:
            self.bns1[node_type] = torch.nn.BatchNorm1d(self.hidden_size, eps=args['eps'])
            self.bns2[node_type] = torch.nn.BatchNorm1d(self.hidden_size, eps=args['eps'])
            self.post_mps[node_type] = nn.Linear(self.hidden_size, hetero_graph.num_node_labels(node_type))
            self.relus1[node_type] = nn.LeakyReLU()
            self.relus2[node_type] = nn.LeakyReLU()

    def forward(self, node_feature, edge_index):
        x = node_feature
        x = self.convs1(x, edge_index)
        x = forward_op(x, self.bns1)
        x = forward_op(x, self.relus1)
        x = self.convs2(x, edge_index)
        x = forward_op(x, self.bns2)
        x = forward_op(x, self.relus2)
        x = forward_op(x, self.post_mps)
        return x

    def loss(self, preds, y, indices):
        loss = 0
        loss_func = F.cross_entropy
        for node_type in preds:
            idx = indices[node_type]
            loss += loss_func(preds[node_type][idx], y[node_type][idx])
        return loss

# %% [markdown]
# ## Training and Testing
#
# Here are the functions to train and test.

# %%
def train(model, optimizer, hetero_graph, train_idx):
    model.train()
    optimizer.zero_grad()
    preds = model(hetero_graph.node_feature, hetero_graph.edge_index)

    loss = model.loss(preds, hetero_graph.node_label, train_idx)
    loss.backward()
    optimizer.step()
    return loss.item()

def test(model, graph, indices, best_model=None, best_val=0):
    model.eval()
    accs = []
    for index in indices:
        preds = model(graph.node_feature, graph.edge_index)
        num_node_types = 0
        micro = 0
        macro = 0
        for node_type in preds:
            idx = index[node_type]
            pred = preds[node_type][idx]
            pred = pred.max(1)[1]
            label_np = graph.node_label[node_type][idx].cpu().numpy()
            pred_np = pred.cpu().numpy()
            micro = f1_score(label_np, pred_np, average='micro')
            macro = f1_score(label_np, pred_np, average='macro')
            num_node_types += 1
        # Averaging f1 score might not make sense, but in our example we only
        # have one node type
        micro /= num_node_types
        macro /= num_node_types
        accs.append((micro, macro))
    if accs[1][0] > best_val:
        best_val = accs[1][0]
        best_model = copy.deepcopy(model)
    return accs, best_model, best_val

# %%
args = {
    'device': torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    'hidden_size': 64,
    'epochs': 100,
    'weight_decay': 1e-5,
    'lr': 0.003,
    'attn_size': 32,
    'eps': 1.0,
}

# %% [markdown]
# ## Dataset and Preprocessing
#
# In the next, we will load the data and create a tensor backend (without a NetworkX graph) `deepsnap.hetero_graph.HeteroGraph` object.
#
# We will use the `ACM(3025)` dataset in our node property prediction task, which is proposed in **HAN** ([Wang et al. (2019)](https://arxiv.org/abs/1903.07293)) and our dataset is extracted from [DGL](https://www.dgl.ai/)'s [ACM.mat](https://data.dgl.ai/dataset/ACM.mat).
#
# Now, let's download the extracted dataset.

# %%
# !wget https://www.dropbox.com/s/8c3102hm4ffm092/acm.pkl
# Out:
# --2025-07-27 12:57:51--  https://www.dropbox.com/s/8c3102hm4ffm092/acm.pkl
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/8xz9tq8d2kikvt1003xlq/acm.pkl?rlkey=3mcovcmbr93y0wtg6y6w50aje [following]
# --2025-07-27 12:57:52--  https://www.dropbox.com/scl/fi/8xz9tq8d2kikvt1003xlq/acm.pkl?rlkey=3mcovcmbr93y0wtg6y6w50aje
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc41434b5434b583872f07aaa3f9.dl.dropboxusercontent.com/cd/0/inline/CuQ-Z12JNVEQzrr_Ml5IftKSgyL0OBbfjWYlL_kiI72gzKE2kh1BGz5DdwVXcwgkK-rhvwPPqUyMem3WYIH_dqjJcKz6pOHoWudGKSg3lkUNswhwX5OB8eH2RpR9xuXBaPG0nLedc-VvjdBkzJIegpaE/file# [following]
# --2025-07-27 12:57:53--  https://uc41434b5434b583872f07aaa3f9.dl.dropboxusercontent.com/cd/0/inline/CuQ-Z12JNVEQzrr_Ml5IftKSgyL0OBbfjWYlL_kiI72gzKE2kh1BGz5DdwVXcwgkK-rhvwPPqUyMem3WYIH_dqjJcKz6pOHoWudGKSg3lkUNswhwX5OB8eH2RpR9xuXBaPG0nLedc-VvjdBkzJIegpaE/file
# Resolving uc41434b5434b583872f07aaa3f9.dl.dropboxusercontent.com (uc41434b5434b583872f07aaa3f9.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6035:15::a27d:550f
# Connecting to uc41434b5434b583872f07aaa3f9.dl.dropboxusercontent.com (uc41434b5434b583872f07aaa3f9.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CuRqJtYuVxrji_972Ef_jW0k1p9UKg9VUf1zqeB4at0es31qIZO4T58-kbrQzN4m5C-aA0HJOrmsmJ5IOppWMbOtFrsHkczBzT1oFc9JpP_6qOdKrQTUqPwCMmTcEmv9SqLddavFTznFWN9XwebFNHK-FQKM6Hz7CGDm4TQuF_F_GgBMNrrQO4hMhQB2mHxx9KjXAuemthtlT_Z61Pd-Wbnt1qkoSL5Tih3NPwyczbSlA2bCrLxYy1hW2J7aIwyuSWjHHHzTn6MFG1YXU1txOoja5faO14lGlerKEqcmdhQgKOD2Lf6KxXF7EYN4XuK77p-k8Cx4xtIyOheejwGDNKz_k1gHTB72PISNCalehk9QPo2wp_KHVPMahdSVgvMmF-4/file [following]
# --2025-07-27 12:57:54--  https://uc41434b5434b583872f07aaa3f9.dl.dropboxusercontent.com/cd/0/inline2/CuRqJtYuVxrji_972Ef_jW0k1p9UKg9VUf1zqeB4at0es31qIZO4T58-kbrQzN4m5C-aA0HJOrmsmJ5IOppWMbOtFrsHkczBzT1oFc9JpP_6qOdKrQTUqPwCMmTcEmv9SqLddavFTznFWN9XwebFNHK-FQKM6Hz7CGDm4TQuF_F_GgBMNrrQO4hMhQB2mHxx9KjXAuemthtlT_Z61Pd-Wbnt1qkoSL5Tih3NPwyczbSlA2bCrLxYy1hW2J7aIwyuSWjHHHzTn6MFG1YXU1txOoja5faO14lGlerKEqcmdhQgKOD2Lf6KxXF7EYN4XuK77p-k8Cx4xtIyOheejwGDNKz_k1gHTB72PISNCalehk9QPo2wp_KHVPMahdSVgvMmF-4/file
# Reusing existing connection to uc41434b5434b583872f07aaa3f9.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 58421685 (56M) [application/octet-stream]
# Saving to: ‘acm.pkl’
#
# acm.pkl             100%[===================>]  55.71M  10.5MB/s    in 5.8s
#
# 2025-07-27 12:58:00 (9.57 MB/s) - ‘acm.pkl’ saved [58421685/58421685]

# %% [markdown]
# The original ACM dataset has three node types and two edge (relation) types. For simplicity, we simplify the heterogeneous graph to one node type and two edge types (shown below). This means that in our heterogeneous graph, we have one node type (paper) and two message types *(paper, author, paper)* and *(paper, subject, paper)*.
#
# <br/>
# <center>
# <img src="http://web.stanford.edu/class/cs224w/images/colab4/cs224w-acm.png"/>
# </center>
#
# Following is the code for dataset preprocessing. Here for efficiency, we only use the tensor backend for the DeepSNAP `HeteroGraph`.

# %%
print("Device: {}".format(args['device']))

# Load the data
data = torch.load("acm.pkl")

# Message types
message_type_1 = ("paper", "author", "paper")
message_type_2 = ("paper", "subject", "paper")

# Dictionary of edge indices
edge_index = {}
edge_index[message_type_1] = data['pap']
edge_index[message_type_2] = data['psp']

# Dictionary of node features
node_feature = {}
node_feature["paper"] = data['feature']

# Dictionary of node labels
node_label = {}
node_label["paper"] = data['label']

# Load the train, validation and test indices
train_idx = {"paper": data['train_idx'].to(args['device'])}
val_idx = {"paper": data['val_idx'].to(args['device'])}
test_idx = {"paper": data['test_idx'].to(args['device'])}

# Construct a deepsnap tensor backend HeteroGraph
hetero_graph = HeteroGraph(
    node_feature=node_feature,
    node_label=node_label,
    edge_index=edge_index,
    directed=True
)

print(f"ACM heterogeneous graph: {hetero_graph.num_nodes()} nodes, {hetero_graph.num_edges()} edges")

# Node feature and node label to device
for key in hetero_graph.node_feature:
    hetero_graph.node_feature[key] = hetero_graph.node_feature[key].to(args['device'])
for key in hetero_graph.node_label:
    hetero_graph.node_label[key] = hetero_graph.node_label[key].to(args['device'])

# Edge_index to sparse tensor and to device
for key in hetero_graph.edge_index:
    edge_index = hetero_graph.edge_index[key]
    adj = SparseTensor(row=edge_index[0], col=edge_index[1], sparse_sizes=(hetero_graph.num_nodes('paper'), hetero_graph.num_nodes('paper')))
    hetero_graph.edge_index[key] = adj.t().to(args['device'])
print(hetero_graph.edge_index[message_type_1])
print(hetero_graph.edge_index[message_type_2])
# Out:
# Device: cuda
# ACM heterogeneous graph: {'paper': 3025} nodes, {('paper', 'author', 'paper'): 26256, ('paper', 'subject', 'paper'): 2207736} edges
# SparseTensor(row=tensor([   0,    0,    0,  ..., 3024, 3024, 3024], device='cuda:0'),
#              col=tensor([   8,   20,   51,  ..., 2948, 2983, 2991], device='cuda:0'),
#              size=(3025, 3025), nnz=26256, density=0.29%)
# SparseTensor(row=tensor([   0,    0,    0,  ..., 3024, 3024, 3024], device='cuda:0'),
#              col=tensor([  75,  434,  534,  ..., 3020, 3021, 3022], device='cuda:0'),
#              size=(3025, 3025), nnz=2207736, density=24.13%)

# %% [markdown]
# ## Start Training!
#
# Now lets start training!

# %% [markdown]
# ## Training the Mean Aggregation

# %%
best_model = None
best_val = 0

model = HeteroGNN(hetero_graph, args, aggr="mean").to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'], weight_decay=args['weight_decay'])

for epoch in range(args['epochs']):
    loss = train(model, optimizer, hetero_graph, train_idx)
    accs, best_model, best_val = test(model, hetero_graph, [train_idx, val_idx, test_idx], best_model, best_val)
    print(
        f"Epoch {epoch + 1}: loss {round(loss, 5)}, "
        f"train micro {round(accs[0][0] * 100, 2)}%, train macro {round(accs[0][1] * 100, 2)}%, "
        f"valid micro {round(accs[1][0] * 100, 2)}%, valid macro {round(accs[1][1] * 100, 2)}%, "
        f"test micro {round(accs[2][0] * 100, 2)}%, test macro {round(accs[2][1] * 100, 2)}%"
    )
best_accs, _, _ = test(best_model, hetero_graph, [train_idx, val_idx, test_idx])
print(
    f"Best model: "
    f"train micro {round(best_accs[0][0] * 100, 2)}%, train macro {round(best_accs[0][1] * 100, 2)}%, "
    f"valid micro {round(best_accs[1][0] * 100, 2)}%, valid macro {round(best_accs[1][1] * 100, 2)}%, "
    f"test micro {round(best_accs[2][0] * 100, 2)}%, test macro {round(best_accs[2][1] * 100, 2)}%"
)
# Out:
# Epoch 1: loss 1.09965, train micro 33.33%, train macro 16.67%, valid micro 33.33%, valid macro 16.67%, test micro 31.29%, test macro 15.89%
# Epoch 2: loss 1.08924, train micro 55.17%, train macro 46.31%, valid micro 54.0%, valid macro 45.24%, test micro 49.55%, test macro 40.41%
# Epoch 3: loss 1.05372, train micro 66.67%, train macro 53.63%, valid micro 65.67%, valid macro 52.93%, test micro 66.12%, test macro 54.13%
# Epoch 4: loss 0.98409, train micro 67.17%, train macro 56.54%, valid micro 66.0%, valid macro 54.82%, test micro 65.65%, test macro 54.58%
# Epoch 5: loss 0.86847, train micro 67.0%, train macro 56.57%, valid micro 66.33%, valid macro 55.22%, test micro 65.36%, test macro 54.48%
# Epoch 6: loss 0.70556, train micro 67.17%, train macro 56.96%, valid micro 66.67%, valid macro 56.05%, test micro 65.32%, test macro 54.46%
# Epoch 7: loss 0.51832, train micro 67.33%, train macro 57.31%, valid micro 66.33%, valid macro 55.81%, test micro 65.36%, test macro 54.59%
# Epoch 8: loss 0.35023, train micro 70.0%, train macro 62.53%, valid micro 66.67%, valid macro 56.45%, test micro 65.46%, test macro 54.72%
# Epoch 9: loss 0.2294, train micro 72.83%, train macro 67.29%, valid micro 69.0%, valid macro 61.18%, test micro 65.6%, test macro 54.99%
# Epoch 10: loss 0.15128, train micro 76.33%, train macro 72.68%, valid micro 72.0%, valid macro 66.49%, test micro 66.07%, test macro 55.79%
# Epoch 11: loss 0.10029, train micro 85.17%, train macro 84.16%, valid micro 79.0%, valid macro 76.93%, test micro 68.0%, test macro 59.55%
# Epoch 12: loss 0.06635, train micro 91.33%, train macro 91.04%, valid micro 87.33%, valid macro 86.94%, test micro 70.73%, test macro 64.6%
# Epoch 13: loss 0.04501, train micro 95.83%, train macro 95.78%, valid micro 91.67%, valid macro 91.52%, test micro 73.93%, test macro 69.84%
# Epoch 14: loss 0.03213, train micro 97.5%, train macro 97.48%, valid micro 92.67%, valid macro 92.52%, test micro 77.13%, test macro 74.43%
# Epoch 15: loss 0.02413, train micro 98.5%, train macro 98.5%, valid micro 94.33%, valid macro 94.25%, test micro 79.91%, test macro 78.11%
# Epoch 16: loss 0.01903, train micro 99.0%, train macro 99.0%, valid micro 96.0%, valid macro 95.96%, test micro 81.6%, test macro 80.26%
# Epoch 17: loss 0.01594, train micro 99.17%, train macro 99.17%, valid micro 96.33%, valid macro 96.31%, test micro 82.87%, test macro 81.82%
# Epoch 18: loss 0.01394, train micro 99.33%, train macro 99.33%, valid micro 97.33%, valid macro 97.33%, test micro 83.53%, test macro 82.64%
# Epoch 19: loss 0.01248, train micro 99.5%, train macro 99.5%, valid micro 97.33%, valid macro 97.33%, test micro 84.0%, test macro 83.21%
# Epoch 20: loss 0.01125, train micro 99.67%, train macro 99.67%, valid micro 97.0%, valid macro 96.99%, test micro 84.24%, test macro 83.53%
# Epoch 21: loss 0.01011, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.33%, test micro 84.56%, test macro 83.93%
# Epoch 22: loss 0.00905, train micro 100.0%, train macro 100.0%, valid micro 97.67%, valid macro 97.66%, test micro 84.38%, test macro 83.73%
# Epoch 23: loss 0.00805, train micro 100.0%, train macro 100.0%, valid micro 97.67%, valid macro 97.66%, test micro 84.47%, test macro 83.82%
# Epoch 24: loss 0.00717, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.32%, test micro 84.52%, test macro 83.88%
# Epoch 25: loss 0.0064, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.32%, test micro 84.33%, test macro 83.69%
# Epoch 26: loss 0.00574, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.32%, test micro 84.14%, test macro 83.5%
# Epoch 27: loss 0.00517, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.33%, test micro 84.24%, test macro 83.62%
# Epoch 28: loss 0.00466, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.33%, test micro 84.47%, test macro 83.87%
# Epoch 29: loss 0.00421, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.33%, test micro 84.42%, test macro 83.83%
# Epoch 30: loss 0.00374, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.01%, test micro 84.42%, test macro 83.88%
# Epoch 31: loss 0.00325, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.01%, test micro 84.0%, test macro 83.44%
# Epoch 32: loss 0.00282, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.01%, test micro 84.05%, test macro 83.49%
# Epoch 33: loss 0.00244, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.34%, test micro 84.14%, test macro 83.6%
# Epoch 34: loss 0.00211, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.34%, test micro 84.19%, test macro 83.67%
# Epoch 35: loss 0.00183, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.34%, test micro 83.91%, test macro 83.4%
# Epoch 36: loss 0.00159, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.34%, test micro 83.95%, test macro 83.48%
# Epoch 37: loss 0.00139, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.34%, test micro 84.09%, test macro 83.64%
# Epoch 38: loss 0.00123, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 84.09%, test macro 83.65%
# Epoch 39: loss 0.0011, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 84.19%, test macro 83.77%
# Epoch 40: loss 0.00099, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 84.28%, test macro 83.88%
# Epoch 41: loss 0.0009, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 84.19%, test macro 83.79%
# Epoch 42: loss 0.00083, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.34%, test micro 84.33%, test macro 83.94%
# Epoch 43: loss 0.00077, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.34%, test micro 84.24%, test macro 83.85%
# Epoch 44: loss 0.00072, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 84.28%, test macro 83.93%
# Epoch 45: loss 0.00068, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.34%, test micro 84.24%, test macro 83.89%
# Epoch 46: loss 0.00065, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.34%, test micro 84.19%, test macro 83.86%
# Epoch 47: loss 0.00061, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 84.09%, test macro 83.78%
# Epoch 48: loss 0.00059, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 84.19%, test macro 83.89%
# Epoch 49: loss 0.00056, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 84.14%, test macro 83.85%
# Epoch 50: loss 0.00054, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 84.05%, test macro 83.78%
# Epoch 51: loss 0.00052, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.81%, test macro 83.54%
# Epoch 52: loss 0.0005, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.86%, test macro 83.6%
# Epoch 53: loss 0.00048, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.81%, test macro 83.56%
# Epoch 54: loss 0.00047, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.76%, test macro 83.52%
# Epoch 55: loss 0.00046, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.72%, test macro 83.48%
# Epoch 56: loss 0.00044, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.34%, test micro 83.72%, test macro 83.48%
# Epoch 57: loss 0.00043, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.58%, test macro 83.34%
# Epoch 58: loss 0.00042, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.58%, test macro 83.34%
# Epoch 59: loss 0.00041, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.58%, test macro 83.34%
# Epoch 60: loss 0.0004, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.72%, test macro 83.49%
# Epoch 61: loss 0.00039, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.86%, test macro 83.64%
# Epoch 62: loss 0.00038, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.91%, test macro 83.69%
# Epoch 63: loss 0.00037, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.91%, test macro 83.7%
# Epoch 64: loss 0.00037, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.91%, test macro 83.71%
# Epoch 65: loss 0.00036, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.86%, test macro 83.66%
# Epoch 66: loss 0.00035, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 84.0%, test macro 83.8%
# Epoch 67: loss 0.00035, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 84.0%, test macro 83.81%
# Epoch 68: loss 0.00034, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 84.0%, test macro 83.81%
# Epoch 69: loss 0.00034, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 84.0%, test macro 83.81%
# Epoch 70: loss 0.00033, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 84.0%, test macro 83.83%
# Epoch 71: loss 0.00033, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 83.91%, test macro 83.73%
# Epoch 72: loss 0.00032, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.68%, test micro 83.91%, test macro 83.73%
# Epoch 73: loss 0.00032, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.68%, test micro 83.91%, test macro 83.73%
# Epoch 74: loss 0.00031, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.01%, test micro 83.86%, test macro 83.7%
# Epoch 75: loss 0.00031, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 84.05%, test macro 83.89%
# Epoch 76: loss 0.0003, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 84.0%, test macro 83.83%
# Epoch 77: loss 0.0003, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.91%, test macro 83.74%
# Epoch 78: loss 0.0003, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.91%, test macro 83.74%
# Epoch 79: loss 0.00029, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.91%, test macro 83.74%
# Epoch 80: loss 0.00029, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.72%, test macro 83.56%
# Epoch 81: loss 0.00029, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.72%, test macro 83.57%
# Epoch 82: loss 0.00028, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.72%, test macro 83.57%
# Epoch 83: loss 0.00028, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.72%, test macro 83.57%
# Epoch 84: loss 0.00028, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.72%, test macro 83.57%
# Epoch 85: loss 0.00027, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.67%, test macro 83.52%
# Epoch 86: loss 0.00027, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.53%, test macro 83.39%
# Epoch 87: loss 0.00027, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.53%, test macro 83.39%
# Epoch 88: loss 0.00027, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.53%, test macro 83.39%
# Epoch 89: loss 0.00026, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.53%, test macro 83.39%
# Epoch 90: loss 0.00026, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.58%, test macro 83.45%
# Epoch 91: loss 0.00026, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.58%, test macro 83.45%
# Epoch 92: loss 0.00026, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.48%, test macro 83.35%
# Epoch 93: loss 0.00025, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.48%, test macro 83.35%
# Epoch 94: loss 0.00025, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.48%, test macro 83.35%
# Epoch 95: loss 0.00025, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.48%, test macro 83.36%
# Epoch 96: loss 0.00025, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.48%, test macro 83.36%
# Epoch 97: loss 0.00024, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.39%, test macro 83.27%
# Epoch 98: loss 0.00024, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.29%, test macro 83.17%
# Epoch 99: loss 0.00024, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.29%, test macro 83.17%
# Epoch 100: loss 0.00024, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 83.29%, test macro 83.17%
# Best model: train micro 100.0%, train macro 100.0%, valid micro 97.67%, valid macro 97.66%, test micro 84.38%, test macro 83.73%

# %% [markdown]
# ## Training the Attention Aggregation

# %%
best_model = None
best_val = 0

output_size = hetero_graph.num_node_labels('paper')
model = HeteroGNN(hetero_graph, args, aggr="attn").to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'], weight_decay=args['weight_decay'])

for epoch in range(args['epochs']):
    loss = train(model, optimizer, hetero_graph, train_idx)
    accs, best_model, best_val = test(model, hetero_graph, [train_idx, val_idx, test_idx], best_model, best_val)
    print(
        f"Epoch {epoch + 1}: loss {round(loss, 5)}, "
        f"train micro {round(accs[0][0] * 100, 2)}%, train macro {round(accs[0][1] * 100, 2)}%, "
        f"valid micro {round(accs[1][0] * 100, 2)}%, valid macro {round(accs[1][1] * 100, 2)}%, "
        f"test micro {round(accs[2][0] * 100, 2)}%, test macro {round(accs[2][1] * 100, 2)}%"
    )
best_accs, _, _ = test(best_model, hetero_graph, [train_idx, val_idx, test_idx])
print(
    f"Best model: "
    f"train micro {round(best_accs[0][0] * 100, 2)}%, train macro {round(best_accs[0][1] * 100, 2)}%, "
    f"valid micro {round(best_accs[1][0] * 100, 2)}%, valid macro {round(best_accs[1][1] * 100, 2)}%, "
    f"test micro {round(best_accs[2][0] * 100, 2)}%, test macro {round(best_accs[2][1] * 100, 2)}%"
)
# Out:
# Epoch 1: loss 1.09998, train micro 33.33%, train macro 16.67%, valid micro 33.33%, valid macro 16.67%, test micro 31.29%, test macro 15.89%
# Epoch 2: loss 1.09151, train micro 33.33%, train macro 16.67%, valid micro 33.33%, valid macro 16.67%, test micro 31.29%, test macro 15.89%
# Epoch 3: loss 1.06424, train micro 45.0%, train macro 35.84%, valid micro 40.33%, valid macro 29.16%, test micro 37.51%, test macro 26.5%
# Epoch 4: loss 1.00966, train micro 67.83%, train macro 59.35%, valid micro 64.67%, valid macro 53.71%, test micro 60.19%, test macro 48.3%
# Epoch 5: loss 0.91517, train micro 70.0%, train macro 61.6%, valid micro 68.0%, valid macro 57.43%, test micro 65.69%, test macro 54.34%
# Epoch 6: loss 0.77676, train micro 69.33%, train macro 60.93%, valid micro 67.67%, valid macro 57.25%, test micro 65.98%, test macro 54.5%
# Epoch 7: loss 0.61045, train micro 70.33%, train macro 62.58%, valid micro 67.67%, valid macro 57.69%, test micro 65.98%, test macro 54.73%
# Epoch 8: loss 0.44964, train micro 71.33%, train macro 64.53%, valid micro 68.67%, valid macro 59.88%, test micro 66.07%, test macro 55.06%
# Epoch 9: loss 0.3216, train micro 74.33%, train macro 69.54%, valid micro 69.0%, valid macro 60.62%, test micro 66.35%, test macro 55.78%
# Epoch 10: loss 0.23219, train micro 77.5%, train macro 74.41%, valid micro 72.67%, valid macro 67.3%, test micro 66.73%, test macro 56.68%
# Epoch 11: loss 0.17193, train micro 84.17%, train macro 82.96%, valid micro 79.0%, valid macro 76.62%, test micro 67.72%, test macro 58.69%
# Epoch 12: loss 0.1294, train micro 90.67%, train macro 90.36%, valid micro 83.67%, valid macro 82.4%, test micro 69.08%, test macro 61.35%
# Epoch 13: loss 0.09744, train micro 93.83%, train macro 93.71%, valid micro 88.33%, valid macro 87.74%, test micro 71.2%, test macro 65.16%
# Epoch 14: loss 0.07297, train micro 95.83%, train macro 95.79%, valid micro 89.33%, valid macro 88.88%, test micro 73.27%, test macro 68.44%
# Epoch 15: loss 0.05468, train micro 96.83%, train macro 96.82%, valid micro 90.67%, valid macro 90.34%, test micro 74.45%, test macro 70.39%
# Epoch 16: loss 0.04166, train micro 97.83%, train macro 97.83%, valid micro 90.67%, valid macro 90.37%, test micro 74.96%, test macro 71.32%
# Epoch 17: loss 0.03227, train micro 98.33%, train macro 98.33%, valid micro 91.33%, valid macro 91.11%, test micro 75.34%, test macro 72.14%
# Epoch 18: loss 0.02539, train micro 98.83%, train macro 98.83%, valid micro 92.33%, valid macro 92.19%, test micro 75.39%, test macro 72.42%
# Epoch 19: loss 0.02008, train micro 99.0%, train macro 99.0%, valid micro 93.0%, valid macro 92.96%, test micro 75.95%, test macro 73.31%
# Epoch 20: loss 0.01595, train micro 99.17%, train macro 99.17%, valid micro 93.33%, valid macro 93.32%, test micro 75.76%, test macro 73.26%
# Epoch 21: loss 0.0128, train micro 99.33%, train macro 99.33%, valid micro 93.67%, valid macro 93.66%, test micro 76.14%, test macro 73.96%
# Epoch 22: loss 0.01036, train micro 99.33%, train macro 99.33%, valid micro 93.67%, valid macro 93.66%, test micro 76.33%, test macro 74.44%
# Epoch 23: loss 0.00844, train micro 99.67%, train macro 99.67%, valid micro 93.33%, valid macro 93.34%, test micro 76.33%, test macro 74.48%
# Epoch 24: loss 0.00696, train micro 99.83%, train macro 99.83%, valid micro 93.0%, valid macro 93.02%, test micro 76.38%, test macro 74.59%
# Epoch 25: loss 0.00566, train micro 99.83%, train macro 99.83%, valid micro 93.0%, valid macro 93.02%, test micro 76.8%, test macro 75.1%
# Epoch 26: loss 0.0045, train micro 99.83%, train macro 99.83%, valid micro 94.33%, valid macro 94.34%, test micro 77.36%, test macro 75.81%
# Epoch 27: loss 0.00358, train micro 99.83%, train macro 99.83%, valid micro 94.33%, valid macro 94.34%, test micro 77.79%, test macro 76.37%
# Epoch 28: loss 0.00286, train micro 100.0%, train macro 100.0%, valid micro 94.0%, valid macro 94.02%, test micro 78.45%, test macro 77.11%
# Epoch 29: loss 0.00232, train micro 100.0%, train macro 100.0%, valid micro 94.33%, valid macro 94.36%, test micro 79.01%, test macro 77.8%
# Epoch 30: loss 0.00192, train micro 100.0%, train macro 100.0%, valid micro 95.33%, valid macro 95.35%, test micro 79.58%, test macro 78.44%
# Epoch 31: loss 0.00162, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 80.09%, test macro 78.97%
# Epoch 32: loss 0.0014, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 80.61%, test macro 79.6%
# Epoch 33: loss 0.00123, train micro 100.0%, train macro 100.0%, valid micro 95.33%, valid macro 95.34%, test micro 81.13%, test macro 80.19%
# Epoch 34: loss 0.0011, train micro 100.0%, train macro 100.0%, valid micro 95.33%, valid macro 95.34%, test micro 81.65%, test macro 80.81%
# Epoch 35: loss 0.00099, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 81.84%, test macro 81.05%
# Epoch 36: loss 0.00089, train micro 100.0%, train macro 100.0%, valid micro 95.33%, valid macro 95.33%, test micro 82.07%, test macro 81.33%
# Epoch 37: loss 0.00082, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.67%, test micro 82.16%, test macro 81.44%
# Epoch 38: loss 0.00075, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.0%, test micro 82.21%, test macro 81.5%
# Epoch 39: loss 0.00069, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.65%, test micro 82.35%, test macro 81.7%
# Epoch 40: loss 0.00064, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.65%, test micro 82.45%, test macro 81.81%
# Epoch 41: loss 0.0006, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.33%, test micro 82.49%, test macro 81.87%
# Epoch 42: loss 0.00056, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.66%, test micro 82.49%, test macro 81.92%
# Epoch 43: loss 0.00052, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.66%, test micro 82.49%, test macro 81.95%
# Epoch 44: loss 0.00049, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.66%, test micro 82.4%, test macro 81.9%
# Epoch 45: loss 0.00047, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.66%, test micro 82.35%, test macro 81.86%
# Epoch 46: loss 0.00044, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.66%, test micro 82.64%, test macro 82.16%
# Epoch 47: loss 0.00042, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.66%, test micro 82.64%, test macro 82.17%
# Epoch 48: loss 0.0004, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.66%, test micro 82.73%, test macro 82.28%
# Epoch 49: loss 0.00038, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.33%, test micro 82.78%, test macro 82.35%
# Epoch 50: loss 0.00037, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.33%, test micro 83.01%, test macro 82.62%
# Epoch 51: loss 0.00035, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.33%, test micro 83.01%, test macro 82.62%
# Epoch 52: loss 0.00034, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.65%, test micro 82.82%, test macro 82.46%
# Epoch 53: loss 0.00033, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.65%, test micro 82.82%, test macro 82.47%
# Epoch 54: loss 0.00031, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.65%, test micro 82.68%, test macro 82.34%
# Epoch 55: loss 0.0003, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.65%, test micro 82.78%, test macro 82.46%
# Epoch 56: loss 0.00029, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.65%, test micro 82.64%, test macro 82.32%
# Epoch 57: loss 0.00029, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 82.4%, test macro 82.1%
# Epoch 58: loss 0.00028, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 82.26%, test macro 81.97%
# Epoch 59: loss 0.00027, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 82.12%, test macro 81.83%
# Epoch 60: loss 0.00026, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 82.07%, test macro 81.78%
# Epoch 61: loss 0.00026, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 82.07%, test macro 81.79%
# Epoch 62: loss 0.00025, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.88%, test macro 81.6%
# Epoch 63: loss 0.00025, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.84%, test macro 81.55%
# Epoch 64: loss 0.00024, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.79%, test macro 81.52%
# Epoch 65: loss 0.00023, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.6%, test macro 81.33%
# Epoch 66: loss 0.00023, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.6%, test macro 81.34%
# Epoch 67: loss 0.00023, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.55%, test macro 81.31%
# Epoch 68: loss 0.00022, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.55%, test macro 81.31%
# Epoch 69: loss 0.00022, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.51%, test macro 81.28%
# Epoch 70: loss 0.00021, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.51%, test macro 81.29%
# Epoch 71: loss 0.00021, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.55%, test macro 81.33%
# Epoch 72: loss 0.00021, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.51%, test macro 81.29%
# Epoch 73: loss 0.0002, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.51%, test macro 81.29%
# Epoch 74: loss 0.0002, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.46%, test macro 81.24%
# Epoch 75: loss 0.0002, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.41%, test macro 81.2%
# Epoch 76: loss 0.00019, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.46%, test macro 81.25%
# Epoch 77: loss 0.00019, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.55%, test macro 81.36%
# Epoch 78: loss 0.00019, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.51%, test macro 81.32%
# Epoch 79: loss 0.00019, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.51%, test macro 81.31%
# Epoch 80: loss 0.00018, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.55%, test macro 81.36%
# Epoch 81: loss 0.00018, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.55%, test macro 81.36%
# Epoch 82: loss 0.00018, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.51%, test macro 81.31%
# Epoch 83: loss 0.00018, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.6%, test macro 81.42%
# Epoch 84: loss 0.00018, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.6%, test macro 81.42%
# Epoch 85: loss 0.00017, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.65%, test macro 81.47%
# Epoch 86: loss 0.00017, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.55%, test macro 81.38%
# Epoch 87: loss 0.00017, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.51%, test macro 81.33%
# Epoch 88: loss 0.00017, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.51%, test macro 81.33%
# Epoch 89: loss 0.00017, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.51%, test macro 81.33%
# Epoch 90: loss 0.00017, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.6%, test macro 81.42%
# Epoch 91: loss 0.00016, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.55%, test macro 81.38%
# Epoch 92: loss 0.00016, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.51%, test macro 81.33%
# Epoch 93: loss 0.00016, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.55%, test macro 81.38%
# Epoch 94: loss 0.00016, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.51%, test macro 81.34%
# Epoch 95: loss 0.00016, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.51%, test macro 81.34%
# Epoch 96: loss 0.00016, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.51%, test macro 81.34%
# Epoch 97: loss 0.00015, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.46%, test macro 81.3%
# Epoch 98: loss 0.00015, train micro 100.0%, train macro 100.0%, valid micro 96.67%, valid macro 96.67%, test micro 81.46%, test macro 81.3%
# Epoch 99: loss 0.00015, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.51%, test macro 81.34%
# Epoch 100: loss 0.00015, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 81.51%, test macro 81.35%
# Best model: train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 82.4%, test macro 82.1%

# %% [markdown]
# ## Attention for each Message Type
#
# Through message type level attention we can learn that which message type is more important to which layer.
#
# Here we will print out and show that each layer pay how much attention on each message type.

# %%
if model.convs1.alpha is not None and model.convs2.alpha is not None:
    for idx, message_type in model.convs1.mapping.items():
        print(f"Layer 1 has attention {model.convs1.alpha[idx]} on message type {message_type}")
    for idx, message_type in model.convs2.mapping.items():
        print(f"Layer 2 has attention {model.convs2.alpha[idx]} on message type {message_type}")
# Out:
# Layer 1 has attention 0.045508041977882385 on message type ('paper', 'author', 'paper')
# Layer 1 has attention 0.9544919729232788 on message type ('paper', 'subject', 'paper')
# Layer 2 has attention 0.660256028175354 on message type ('paper', 'author', 'paper')
# Layer 2 has attention 0.33974403142929077 on message type ('paper', 'subject', 'paper')

# %% [markdown]
# More heterogeneous node classification examples please see the [examples/node_classification_hetero](https://github.com/snap-stanford/deepsnap/tree/master/examples/node_classification_hetero).
